# %%
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('C:/Users/Kiana/OneDrive/Documents/GitHub/sunnyhills/data/current/current_key.csv')
data
# Out:
#            tid              GDR2_ID   GDR2_RA  GDR2_DEC  TLC  mas_parrallax  \
# 0    334224777   215799708371288320   89.7318   52.7962   -1          10.46
# 1    408411330  2744912366219351808  357.2139    6.7186   -1          17.92
# 2    167572975  5286418719136987136  101.5367  -63.6858   22          11.19
# 3    364292985  5996114407868087680  239.1308  -40.4704   -1          10.97
# 4    134893921  4067480504879944064  269.1262  -24.8038   22          10.46
# ..         ...                  ...       ...       ...  ...            ...
# 934   58543110   152316037288384640   65.9000   27.0968   18          12.85
# 935  140045538  6558208838138808576  329.4214  -51.0078   -1          67.29
# 936  166852313  4742040513540707072   40.4478  -52.9919   -1          23.03
# 937  289840926  6801191424589717888  317.6294  -27.1813   -1          24.85
# 938  359766629  5841394189606679040  185.1502  -73.8842   22          10.01
#
# ...

# %%
print("Original 'input.csv' CSV Data: \n")

keep = data.GDR2_RA


data.drop('tid', inplace=True, axis=1)
data.drop('GDR2_ID', inplace=True, axis=1)
data.drop('GDR2_RA', inplace=True, axis=1)
data.drop('GDR2_DEC', inplace=True, axis=1)
data.drop('TLC', inplace=True, axis=1)
data.drop('tid', inplace=True, axis=1)
data.drop('tid', inplace=True, axis=1)
data.drop('tid', inplace=True, axis=1)


print("\nCSV Data after deleting the column 'tid', 'GDR2_ID':\n")
print(data)
